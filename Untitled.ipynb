# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
def get_page( url):
        
        page = None

        try:
                       
            with uReq(url) as uClient:
                page = uClient.read()
        except Exception as ex:
            print(ex)
        finally:
            if uClient:
                uClient.close()
            

        return page

# %%
def get_page_html( page):
        html = bs(page, "html.parser")
        return html

# %%
homePage = get_page("https://courses.ineuron.ai/")

# %%
homt_page_html = get_page_html(homePage)

# %%
st = homt_page_html.body.script.string

# %%
homePage
# Out:
# b'<!DOCTYPE html><html><head><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.15.3/css/all.min.css" integrity="sha512-iBBXm8fW90+nuLcSKlbmrPcLa0OT92xO1BIsZ+ywDWZCvqsWgccV3gFoRBv0z+8dLJgyAHIhR35VZc2oM/gI1w==" crossorigin="anonymous"/><link rel="apple-touch-icon" sizes="180x180" href="/images/favicon/apple-touch-icon.png"/><link rel="icon" type="image/png" sizes="32x32" href="/images/favicon/favicon-32x32.png"/><link rel="icon" type="image/png" sizes="16x16" href="/images/favicon/favicon-16x16.png"/><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Swiper/6.8.4/swiper-bundle.min.css"/><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><meta name="next-head-count" content="2"/><link rel="preload" href="/_next/static/css/08475b55a6b71478d7ed.css" as="style"/><link rel="stylesheet" href="/_next/static/css/08475b55a6b71478d7ed.css" data-n-g=""/><link rel="preload" href="/_next/static/css/a2f04b47b0812d1e2629.css" a
# ...

# %%
st
# Out:
# '{"props":{"pageProps":{"initialState":{"auth":{"isLoggedIn":false,"user":{},"isInitialCheckDone":false},"init":{"categories":{"603fa55d8c5e6f4b0ce22d50":{"title":"Data Science","subCategories":{"6041237d03889537f8de7fd2":{"title":"Full Stack Data Science","id":"6041237d03889537f8de7fd2"},"6040887d9d3f6e2c78634be1":{"title":"Machine Learning","id":"6040887d9d3f6e2c78634be1"},"6041201903889537f8de7fce":{"title":"Deep Learning","id":"6041201903889537f8de7fce"},"6041201903889537f8de7fd2":{"title":"Computer Vision","id":"6041201903889537f8de7fd2"},"6041201903889537f8de7fd3":{"title":"AIOps","id":"6041201903889537f8de7fd3"},"6041201903889537f8de8fe3":{"title":"Statistics","id":"6041201903889537f8de8fe3"},"606d2587c2a66a0488269386":{"title":"NLP","id":"606d2587c2a66a0488269386"},"606d258fc2a66a0488269387":{"title":"Data Analysis","id":"606d258fc2a66a0488269387"},"612497c04fe868a9eec16803":{"title":"Big Data","id":"612497c04fe868a9eec16803"}}},"6041220403889537f8de7fcf":{"title":"Developmen
# ...

# %%
import json

# %%
di = json.loads(st)

# %%
categories = di["props"]["pageProps"]["initialState"]["init"]["categories"]

# %%
categories
# Out:
# {'603fa55d8c5e6f4b0ce22d50': {'title': 'Data Science',
#   'subCategories': {'6041237d03889537f8de7fd2': {'title': 'Full Stack Data Science',
#     'id': '6041237d03889537f8de7fd2'},
#    '6040887d9d3f6e2c78634be1': {'title': 'Machine Learning',
#     'id': '6040887d9d3f6e2c78634be1'},
#    '6041201903889537f8de7fce': {'title': 'Deep Learning',
#     'id': '6041201903889537f8de7fce'},
#    '6041201903889537f8de7fd2': {'title': 'Computer Vision',
#     'id': '6041201903889537f8de7fd2'},
#    '6041201903889537f8de7fd3': {'title': 'AIOps',
#     'id': '6041201903889537f8de7fd3'},
#    '6041201903889537f8de8fe3': {'title': 'Statistics',
#     'id': '6041201903889537f8de8fe3'},
#    '606d2587c2a66a0488269386': {'title': 'NLP',
#     'id': '606d2587c2a66a0488269386'},
#    '606d258fc2a66a0488269387': {'title': 'Data Analysis',
#     'id': '606d258fc2a66a0488269387'},
#    '612497c04fe868a9eec16803': {'title': 'Big Data',
#     'id': '612497c04fe868a9eec16803'}}},
# ...

# %%
for key, value in di["props"]["pageProps"]["initialState"]["init"]["courses"].items():
    print(key)
    print(value["categoryId"])
# Out:
# Salesforce Administrator
# 62559b4157c6613f047d3c4c
# Full Stack Data Science Bootcamp
# 6041237d03889537f8de7fd2
# AWS Data Engineering
# 606d2681c2a66a048826948d
# Seminar in MMMUT Community Event
# 6221ce0c760e3e8155f81a07
# Big Data Live Class
# 612497c04fe868a9eec16803
# Reasoning Live Class
# 612497c04fe868a9eec16890
# Spark AR Live Class
# 6203d235d9c2a46996489de9
# Power BI Live Class
# 606d258fc2a66a0488269387
# Deep Learning Live Class
# 6041201903889537f8de7fce
# Foundations of English Language
# 61fcf28fc5aea106db4bbc39
# Android Programming with Machine Learning Apps
# 604125d303889537f8de7fd6
# Pro Backend Developer
# 604125cc03889537f8de7fd5
# Android Chat app with FireBase
# 604125d303889537f8de7fd6
# AWS Architect for Real World
# 606d2681c2a66a048826948d
# Complete ReactJS Developer Bootcamp
# 604125cc03889537f8de7fd5
# Complete Bootstrap - 5 Projects
# 604125cc03889537f8de7fd5
# Django Course
# 604125cc03889537f8de7fd5
# Back-end development with Django-8 Projects
# ...

# %%
di["props"]["pageProps"]["initialState"]["init"]#["courses"]  #['Full Stack Data Science Bootcamp']['categoryId']
# Out:
# {'categories': {'603fa55d8c5e6f4b0ce22d50': {'title': 'Data Science',
#    'subCategories': {'6041237d03889537f8de7fd2': {'title': 'Full Stack Data Science',
#      'id': '6041237d03889537f8de7fd2'},
#     '6040887d9d3f6e2c78634be1': {'title': 'Machine Learning',
#      'id': '6040887d9d3f6e2c78634be1'},
#     '6041201903889537f8de7fce': {'title': 'Deep Learning',
#      'id': '6041201903889537f8de7fce'},
#     '6041201903889537f8de7fd2': {'title': 'Computer Vision',
#      'id': '6041201903889537f8de7fd2'},
#     '6041201903889537f8de7fd3': {'title': 'AIOps',
#      'id': '6041201903889537f8de7fd3'},
#     '6041201903889537f8de8fe3': {'title': 'Statistics',
#      'id': '6041201903889537f8de8fe3'},
#     '606d2587c2a66a0488269386': {'title': 'NLP',
#      'id': '606d2587c2a66a0488269386'},
#     '606d258fc2a66a0488269387': {'title': 'Data Analysis',
#      'id': '606d258fc2a66a0488269387'},
#     '612497c04fe868a9eec16803': {'title': 'Big Data',
# ...

# %%
type(categories) #https://courses.ineuron.ai/Full-Stack-Data-Science-Bootcamp
# Out:
# dict

# %%
for item in categories.keys():
    print("Course: " + categories[item]['title'])
    subCategory = categories[item]['subCategories']
    #print(categories[item]['subCategories'])
    for sub in subCategory.keys():
        print(subCategory[sub])
        
    print(item)
# Out:
# Course: Data Science
# {'title': 'Full Stack Data Science', 'id': '6041237d03889537f8de7fd2'}
# {'title': 'Machine Learning', 'id': '6040887d9d3f6e2c78634be1'}
# {'title': 'Deep Learning', 'id': '6041201903889537f8de7fce'}
# {'title': 'Computer Vision', 'id': '6041201903889537f8de7fd2'}
# {'title': 'AIOps', 'id': '6041201903889537f8de7fd3'}
# {'title': 'Statistics', 'id': '6041201903889537f8de8fe3'}
# {'title': 'NLP', 'id': '606d2587c2a66a0488269386'}
# {'title': 'Data Analysis', 'id': '606d258fc2a66a0488269387'}
# {'title': 'Big Data', 'id': '612497c04fe868a9eec16803'}
# 603fa55d8c5e6f4b0ce22d50
# Course: Development
# {'title': 'Web Development', 'id': '604125cc03889537f8de7fd5'}
# {'title': 'Blockchain', 'id': '61e571f1a2fb22a355eec48d'}
# {'title': 'Mobile Development', 'id': '604125d303889537f8de7fd6'}
# {'title': 'IoT', 'id': '6200dbae3335a899c0f21369'}
# {'title': 'AR_VR', 'id': '6203d235d9c2a46996489de9'}
# {'title': 'Cyber Security', 'id': '6203d1f8d9c2a46996489de5'}
# ...

# %%
detailsPage = get_page(")
# Out:
#   Input In [16]
#     detailsPage = get_page(")
#                              ^
# SyntaxError: EOL while scanning string literal

# %%
detailsPage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <module>
# ----> 1 detailsPage
#
# NameError: name 'detailsPage' is not defined

# %%
detailsPageHTML = get_page_html(detailsPage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <module>
# ----> 1 detailsPageHTML = get_page_html(detailsPage)
#
# NameError: name 'detailsPage' is not defined

# %%
detailsPageHTML
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <module>
# ----> 1 detailsPageHTML
#
# NameError: name 'detailsPageHTML' is not defined

# %%
detailsPageHTML.body.div
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <module>
# ----> 1 detailsPageHTML.body.div
#
# NameError: name 'detailsPageHTML' is not defined

# %%
 detailsPageHTML.select("div")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <module>
# ----> 1 detailsPageHTML.select("div")
#
# NameError: name 'detailsPageHTML' is not defined

# %%
bigboxes = detailsPageHTML.findAll("div", {"id": "__next"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <module>
# ----> 1 bigboxes = detailsPageHTML.findAll("div", {"id": "__next"})
#
# NameError: name 'detailsPageHTML' is not defined

# %%
bigboxes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <module>
# ----> 1 bigboxes
#
# NameError: name 'bigboxes' is not defined

# %%
with uReq("https://courses.ineuron.ai/Full-Stack-Data-Science-Bootcamp") as uClient:
    page = uClient.read()

# %%
page
# Out:
# b'<!DOCTYPE html><html><head><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.15.3/css/all.min.css" integrity="sha512-iBBXm8fW90+nuLcSKlbmrPcLa0OT92xO1BIsZ+ywDWZCvqsWgccV3gFoRBv0z+8dLJgyAHIhR35VZc2oM/gI1w==" crossorigin="anonymous"/><link rel="apple-touch-icon" sizes="180x180" href="/images/favicon/apple-touch-icon.png"/><link rel="icon" type="image/png" sizes="32x32" href="/images/favicon/favicon-32x32.png"/><link rel="icon" type="image/png" sizes="16x16" href="/images/favicon/favicon-16x16.png"/><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Swiper/6.8.4/swiper-bundle.min.css"/><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><meta name="next-head-count" content="2"/><link rel="preload" href="/_next/static/css/08475b55a6b71478d7ed.css" as="style"/><link rel="stylesheet" href="/_next/static/css/08475b55a6b71478d7ed.css" data-n-g=""/><link rel="preload" href="/_next/static/css/a2f04b47b0812d1e2629.css" a
# ...

# %%
import requests

# %%
prodRes = requests.get("https://courses.ineuron.ai/Full-Stack-Data-Science-Bootcamp")
prodRes.encoding='utf-8'

# %%
prod_html = bs(prodRes.text, "html.parser")

# %%
details = prod_html.body.script.string

# %%
j_details = json.loads(details)

# %%
j_details['props']['pageProps']['data']['title']
# Out:
# 'Full Stack Data Science Bootcamp'

# %%
j_details['props']['pageProps']['data']['details']['description']
# Out:
# 'Full-stack data science course is a live mentor-led job guaranteed certification program with a full-time one-year internship provided by iNeuron, in this course you will learn the entire stack required to work in the data science, data analytics, and big data domain, including machine learning, deep learning, computer vision NLP and Big data including MLOps and cloud infrastructure, along with real-time industry projects and product development with the iNeuron product development team, which will enable you to contribute on various levels.'

# %%
j_details['props']['pageProps']['data']['meta']['curriculum'].values()
# Out:
# dict_values([{'title': 'Python Basics', 'items': [{'title': 'Python Introduction, Installation and Setup', 'previewUrl': 'https://player.vimeo.com/video/517568017?h=c7ce94b633&title=0&byline=0&portrait=0&playsinline=0&autoplay=1&autopause=0&app_id=122963'}, {'title': 'Python Basics & Conditionals', 'previewUrl': 'https://player.vimeo.com/video/517869661?h=f646fca311&title=0&byline=0&portrait=0&playsinline=0&autoplay=1&autopause=0&app_id=122963'}, {'title': 'Conditionals & Loops', 'previewUrl': ''}, {'title': 'Working with Loops', 'previewUrl': ''}, {'title': 'Working with Strings & Lists', 'previewUrl': ''}, {'title': 'List manipulation', 'previewUrl': ''}, {'title': 'Tuple, Set & Dictionary', 'previewUrl': ''}, {'title': 'Working with Functions', 'previewUrl': ''}, {'title': 'Functions, Generators & File Handling', 'previewUrl': ''}, {'title': 'Logging and debugging', 'previewUrl': ''}, {'title': 'Modules and Exception', 'previewUrl': ''}]}, {'title': 'OOPS', 'items': [{'title': 'OO
# ...

# %%
l1 = []
for i in j_details['props']['pageProps']['data']['meta']['curriculum'].values():
    name = i["title"] + ": " 
     
    print(i["title"])
    for j in i["items"]:
        name += j["title"]
    l1.append(name)
    #print(name)
print(l1)
# Out:
# Python Basics
# OOPS
# Databases
# Pandas
# Numpy
# Matplotlib
# Plotly
# Seaborn
# EDA
# Web Frameworks
# Python Projects with Deployment
# Stats
# Machine Learning
# ML Projects
# ML Project 1 :- Fault detection in wafers based on sensor data
# ML Project 2 :- Cement Strength Prediction
# ML Project 3 :- Credit Card Defaulters
# ML Project 4 :- Forest Cover
# ML Project 5 :- Income Prediction
# ML Project 6 :- Insurance Fraud Detection
# ML Project 7 :- Mushroom Classification
# ML Project 8 :- Phishing Classifier
# ML Project 9 :- Thyroid Detection
# ML Project 10 :- Visibility Climate
# Time Series
# DL ANN - Introduction
# DL ANN - Perceptron
# DL ANN -1
# DL ANN - 2
# DL ANN - 3
# DL ANN - 4
# DL ANN - 5
# Computer Vision - Introduction
# Computer Vision - CNN Foundations
# Computer Vision - CNN Architectures
# Computer Vision - Image Classification Hyper Parameter Tuning
# Computer Vision - Data Augmentation
# Computer Vision - Object Detection Basics
# ...

# %%
j_details['props']['pageProps']['data']['meta']
# Out:
# {'instructors': ['6187a900f07f73543ccb695c',
#   '618929e26e59b248b8c04aa6',
#   '619370a59db36f163876b413'],
#  'duration': '',
#  'certificateBenchmark': 75,
#  'curriculum': {'6248124a006e092bb359f446': {'title': 'Python Basics',
#    'items': [{'title': 'Python Introduction, Installation and Setup',
#      'previewUrl': 'https://player.vimeo.com/video/517568017?h=c7ce94b633&title=0&byline=0&portrait=0&playsinline=0&autoplay=1&autopause=0&app_id=122963'},
#     {'title': 'Python Basics & Conditionals',
#      'previewUrl': 'https://player.vimeo.com/video/517869661?h=f646fca311&title=0&byline=0&portrait=0&playsinline=0&autoplay=1&autopause=0&app_id=122963'},
#     {'title': 'Conditionals & Loops', 'previewUrl': ''},
#     {'title': 'Working with Loops', 'previewUrl': ''},
#     {'title': 'Working with Strings & Lists', 'previewUrl': ''},
#     {'title': 'List manipulation', 'previewUrl': ''},
#     {'title': 'Tuple, Set & Dictionary', 'previewUrl': ''},
# ...

# %%
j_details['props']['pageProps']
# Out:
# {'isLive': False,
#  'slug': 'Full-Stack-Data-Science-Bootcamp',
#  'data': {'_id': '6248124a006e09832559f938',
#   'title': 'Full Stack Data Science Bootcamp',
#   'isJobGuaranteeProgram': True,
#   'courseInOneNeuron': False,
#   'batches': {},
#   'details': {'categoryId': '6041237d03889537f8de7fd2',
#    'active': True,
#    'seo': {'keywords': 'Full Stack Data Science Bootcamp'},
#    'faq': [],
#    'description': 'Full-stack data science course is a live mentor-led job guaranteed certification program with a full-time one-year internship provided by iNeuron, in this course you will learn the entire stack required to work in the data science, data analytics, and big data domain, including machine learning, deep learning, computer vision NLP and Big data including MLOps and cloud infrastructure, along with real-time industry projects and product development with the iNeuron product development team, which will enable you to contribute on various levels.',
# ...

# %%
overview

# %%
j_details['props']['pageProps']['course']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [69], in <module>
# ----> 1 j_details['props']['pageProps']['course']
#
# KeyError: 'course'

# %%
j_details['props']['pageProps']['data']['meta']['overview']['learn']
# Out:
# ['Python',
#  'Stats',
#  'Machine learning',
#  'Deep learning',
#  'Computer vision',
#  'Natural language processing',
#  'Data analytics',
#  'Big data',
#  'Ml ops',
#  'Cloud',
#  'Data structure and algorithm',
#  'Architecture',
#  'Domain wise project',
#  'Databases',
#  'Negotiations skills',
#  'Mock interview',
#  'Interview preparation',
#  'Resume building after every module']

# %%
j_details['props']['pageProps']['initialState']['init']['instructors']['6187a900f07f73543ccb695c']['name']
# Out:
# 'Sunny Bhaveen Chandra'

# %%
for i in j_details['props']['pageProps']['initialState']['init']['instructors'].values():
    #print(i['name'])
    print(i)
# Out:
# {'img': {'source': 'bucket', 'link': 'Sunny iNeuron.png'}, 'name': 'Sunny Bhaveen Chandra', 'social': {'linkedin': 'https://www.linkedin.com/in/c17hawke/', 'instagram': 'https://www.instagram.com/c17hawke', 'facebook': 'https://m.facebook.com/c17hawke', 'youtube': 'https://www.youtube.com/c/c17hawke', 'github': 'https://github.com/c17hawke'}, 'description': 'Sr. Data Scientist and lecturer at iNeuron.ai with working experience in computer vision, natural language processing and embedded systems. Hands-on experience leveraging machine learning, deep learning, transfer learning models to solve challenging business problems. Also, he has a vast interest in Robotics.', 'email': 'sunny@ineuron.ai'}
# ...

# %%
j_details['props']['pageProps']['initialState']['init']['courses']['Full Stack Data Science Bootcamp']
# Out:
# {'_id': '6248124a006e09832559f938',
#  'platformType': 'main',
#  'description': 'Full-stack data science course is a live mentor-led job guaranteed certification program with a full-time one-year internship provided by iNeuron, in this course you will learn the entire stack required to work in the data science, data analytics, and big data domain, including machine learning, deep learning, computer vision NLP and Big data including MLOps and cloud infrastructure, along with real-time industry projects and product development with the iNeuron product development team, which will enable you to contribute on various levels.',
#  'mode': 'self-paced',
#  'seo': {'keywords': 'Full Stack Data Science Bootcamp'},
#  'batches': [{'isActive': True,
#    '_id': '62495cd87956b9f3867fca08',
#    'title': '',
#    'startDate': '7th May 2022',
#    'timings': '03:00 PM to 06:00 PM (IST) Saturday - Sunday',
#    'doubtClearing': '06:00 PM IST to 08:00 PM IST (IST) Saturday - Sunday'}],
# ...

# %%
j_details['props']['pageProps']['initialState']['init']['courses']['Full Stack Data Science Bootcamp']['courseMeta'][0]['instructors']
# Out:
# ['6187a900f07f73543ccb695c',
#  '618929e26e59b248b8c04aa6',
#  '619370a59db36f163876b413']

# %%
j_details['props']['pageProps']['initialState']['init']['courses']['Full Stack Data Science Bootcamp']['batches'][0]['timings']
# Out:
# '03:00 PM to 06:00 PM (IST) Saturday - Sunday'

# %%
j_details['props']['pageProps']['initialState']['init']['courses']['Graph ML']['batches']
# Out:
# []

# %%
import pandas

# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import json

from bson import json_util, ObjectId
import json

# %%
pymongo.MongoClient("mongodb+srv://admin:123@cluster0.tsqtv.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
# Out:
# MongoClient(host=['cluster0-shard-00-00.tsqtv.mongodb.net:27017', 'cluster0-shard-00-01.tsqtv.mongodb.net:27017', 'cluster0-shard-00-02.tsqtv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-sguhs5-shard-0', tls=True)
